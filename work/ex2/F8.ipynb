# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# F8. （自由課題１）OpenStreetMapのデータを用いたテーマを自由に設定し、データを抽出し、結果を地図で示せ
#
# 茨城県内の駅を抽出し、地図に表示する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    SELECT pt.*
    FROM planet_osm_point pt, adm2 poly
    WHERE pt.public_transport = 'station' AND
    poly.name_1='Ibaraki' AND
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    5677061684   None           None             None               None
# 1     823277434   None           None             None               None
# 2     823277290   None           None             None               None
# 3     264412876   None           None             None               None
# 4    3730494267   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 138  2447142753   None           None             None               None
# 139  3799418511   None           None             None               None
# 140   264413560   None           None             None               None
# 141   264413611   None           None             None               None
# 142   264413561   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle brand bridge  \
# 0          None      None    None    None  None    None    None  None   None
# 1          None      None    None    None  None    None    None  None   None
# 2          None      None    None    None  None    None    None  None   None
# 3          None      None    None    None  None    None    None  None   None
# 4          None      None    None    None  None    None    None  None   None
# ..          ...       ...     ...     ...   ...     ...     ...   ...    ...
# 138        None      None    None    None  None    None    None  None   None
# 139        None      None    None    None  None    None    None  None   None
# 140        None      None    None    None  None    None    None  None   None
# 141        None      None    None    None  None    None    None  None   None
# 142        None      None    None    None  None    None    None  None   None
#
#     boundary building capital construction covered culvert cutting  \
# 0       None     None    None         None    None    None    None
# 1       None     None    None         None    None    None    None
# 2       None     None    None         None    None    None    None
# 3       None     None    None         None    None    None    None
# 4       None     None    None         None    None    None    None
# ..       ...      ...     ...          ...     ...     ...     ...
# 138     None     None    None         None    None    None    None
# 139     None     None    None         None    None    None    None
# 140     None     None    None         None    None    None    None
# 141     None     None    None         None    None    None    None
# 142     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 138         None    None  None       None  None             None    None
# 139         None    None  None       None  None             None    None
# 140         None    None  None       None  None             None    None
# 141         None    None  None       None  None             None    None
# 142         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 138    None     None  None         None     None    None  None    None  None
# 139    None     None  None         None     None    None  None    None  None
# 140    None     None  None         None     None    None  None    None  None
# 141    None     None  None         None     None    None  None    None  None
# 142    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar  name natural office oneway           operator  \
# 0       None     None     None    大洗    None   None   None               None
# 1       None     None     None    折本    None   None   None               真岡鐵道
# 2       None     None     None   ひぐち    None   None   None               真岡鐵道
# 3       None     None     None    新治    None   None   None               None
# 4       None     None     None    下館    None   None   None  東日本旅客鉄道;関東鉄道;真岡鐵道
# ..       ...      ...      ...   ...     ...    ...    ...                ...
# 138     None     None     None  北浦湖畔    None   None   None               None
# 139     None     None     None    延方    None   None   None               None
# 140     None     None     None    結城    None   None   None               None
# 141     None     None     None   東結城    None   None   None               None
# 142     None     None     None   小田林    None   None   None               None
#
#     place   poi population power power_source public_transport  railway   ref  \
# 0    None  None       None  None         None          station  station  None
# 1    None  None       None  None         None          station  station  None
# 2    None  None       None  None         None          station  station  None
# 3    None  None       None  None         None          station  station  None
# 4    None  None       None  None         None          station  station  None
# ..    ...   ...        ...   ...          ...              ...      ...   ...
# 138  None  None       None  None         None          station  station  None
# 139  None  None       None  None         None          station  station  None
# 140  None  None       None  None         None          station  station  None
# 141  None  None       None  None         None          station  station  None
# 142  None  None       None  None         None          station  station  None
#
#     religion route service  shop sport surface  toll tourism tower:type  \
# 0       None  None    None  None  None    None  None    None       None
# 1       None  None    None  None  None    None  None    None       None
# 2       None  None    None  None  None    None  None    None       None
# 3       None  None    None  None  None    None  None    None       None
# 4       None  None    None  None  None    None  None    None       None
# ..       ...   ...     ...   ...   ...     ...   ...     ...        ...
# 138     None  None    None  None  None    None  None    None       None
# 139     None  None    None  None  None    None  None    None       None
# 140     None  None    None  None  None    None  None    None       None
# 141     None  None    None  None  None    None  None    None       None
# 142     None  None    None  None  None    None  None    None       None
#
#     tunnel water waterway wetland width  wood z_order  \
# 0     None  None     None    None  None  None    None
# 1     None  None     None    None  None  None    None
# 2     None  None     None    None  None  None    None
# 3     None  None     None    None  None  None    None
# 4     None  None     None    None  None  None    None
# ..     ...   ...      ...     ...   ...   ...     ...
# 138   None  None     None    None  None  None    None
# 139   None  None     None    None  None  None    None
# 140   None  None     None    None  None  None    None
# 141   None  None     None    None  None  None    None
# 142   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15647391.855 4344062.029)
# 1    POINT (15581526.684 4347591.271)
# 2     POINT (15581438.897 4350060.61)
# 3    POINT (15589147.249 4345888.753)
# 4    POINT (15582358.007 4342556.037)
# ..                                ...
# 138   POINT (15644493.563 4317211.22)
# 139  POINT (15650280.139 4294858.146)
# 140  POINT (15570530.055 4341722.932)
# 141  POINT (15572621.169 4341518.554)
# 142  POINT (15568455.204 4342083.618)
#
# [143 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_582a3d91cda4a0f44ee50883b614e85c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_582a3d91cda4a0f44ee50883b614e85c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_582a3d91cda4a0f44ee50883b614e85c = L.map(
#                 &quot;map_582a3d91cda4a0f44ee50883b614e85c&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c76ce0e90212bb856d0a58051841a11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c76ce0e90212bb856d0a58051841a11.addTo(map_582a3d91cda4a0f44ee50883b614e85c);
#
#
#             var marker_4087ba5f21d2105f065c9be6aeea2922 = L.marker(
#                 [36.31507329976828, 140.5629126],
#                 {
# }
#             ).addTo(map_582a3d91cda4a0f44ee50883b614e85c);
#
#
#         var popup_cb262812eed836af029ef12a0ec8b445 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e33cc5425eaf29a5f8608a8ec2f097c = $(`&lt;div id=&quot;html_4e33cc5425eaf29a5f8608a8ec2f097c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大洗&lt;/div&gt;`)[0];
#                 popup_cb262812eed836af029ef12a0ec8b445.setContent(html_4e33cc5425eaf29a5f8608a8ec2f097c);
#
#
#
#         marker_4087ba5f21d2105f065c9be6aeea2922.bindPopup(popup_cb262812eed836af029ef12a0ec8b445)
#         ;
#
#
#
#
#             var marker_a9475bea60606045dc0d0373517489f4 = L.marker(
#                 [36.34061509977104, 139.9712357],
#                 {
# }
#             ).addTo(map_582a3d91cda4a0f44ee50883b614e85c);
#
#
#         var popup_6e17b9f0028dbaf14cd03f4f7e6d02ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6316e5acd92b6d504b991ea924e43847 = $(`&lt;div id=&quot;html_6316e5acd92b6d504b991ea924e43847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;折本&lt;/div&gt;`)[0];
#                 popup_6e17b9f0028dbaf14cd03f4f7e6d02ca.setContent(html_6316e5acd92b6d504b991ea924e43847);
#
#
#
#         marker_a9475bea60606045dc0d0373517489f4.bindPopup(popup_6e17b9f0028dbaf14cd03f4f7e6d02ca)
#         ;
#
#
#
#
#             var marker_ebbcd84674ade9e1d4527d1424afc20d = L.marker(
#                 [36.358481199772996, 139.9704471],
#                 {
# }
#             ).addTo(map_582a3d91cda4a0f44ee50883b614e85c);
#
#
#         var popup_b7b42edcfbc0801281310e7dcdd86358 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d17d1c942e44fd0db158d65a21537a61 = $(`&lt;div id=&quot;html_d17d1c942e44fd0db158d65a21537a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ひぐち&lt;/div&gt;`)[0];
#                 popup_b7b42edcfbc0801281310e7dcdd86358.setContent(html_d17d1c942e44fd0db158d65a21537a61);
#
#
#
#         marker_ebbcd84674ade9e1d4527d1424afc20d.bindPopup(popup_b7b42edcfbc0801281310e7dcdd86358)
#         ;
#
#
#
#
#             var marker_e0bcf0c2b710e5c2521ceff34a205a63 = L.marker(
#                 [36.3282946997697, 140.0396924],
#                 {
# }
#             ).addTo(map_582a3d91cda4a0f44ee50883b614e85c);
#
#
#         var popup_c5e1627e39e2b094e61ef9adcb863222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_762eca236dbde3e0b0a6b300402aebda = $(`&lt;div id=&quot;html_762eca236dbde3e0b0a6b300402aebda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;新治&lt;/div&gt;`)[0];
#                 popup_c5e1627e39e2b094e61ef9adcb863222.setContent(html_762eca236dbde3e0b0a6b300402aebda);
#
#
#
#         marker_e0bcf0c2b710e5c2521ceff34a205a63.bindPopup(popup_c5e1627e39e2b094e61ef9adcb863222)
#         ;
#
#
#
#
#             var marker_4dd94d5dc43ea7fc205c80ea6738305c = L.marker(
#                 [36.30417159976708, 139.9787036],
#                 {
# }
#             ).addTo(map_582a3d91cda4a0f44ee50883b614e85c);
#
#
#         var popup_9f36b5cce019ca67d4000b28fd52f38f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b95a6cfb1abff9a9b57ccfe4850ae673 = $(`&lt;div id=&quot;html_b95a6cfb1abff9a9b57ccfe4850ae673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;下館&lt;/div&gt;`)[0];
#                 popup_9f36b5cce019ca67d4000b28fd52f38f.setContent(html_b95a6cfb1abff9a9b57ccfe4850ae673);
#
#
#
#         marker_4dd94d5dc43ea7fc205c80ea6738305c.bindPopup(popup_9f36b5cce019ca67d4000b28fd52f38f)
#         ;
#
#
#
#
#             var marker_9b533ccf364c714b2a64949e175f378e = L.marker(
#                 [36.31933409976873, 139.9720269],
